# %%
import pandas as pd

# %%
df_los_angeles = pd.read_csv("../data/los_angeles.csv")
df_los_angeles.head()

# %%
df_new_york = pd.read_csv("../data/new_york.csv")
df_new_york.head()

# %%
df_new_york.columns
