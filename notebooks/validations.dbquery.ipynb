-- %%
SELECT COUNT(*) AS listings_la FROM airbnb_lab3.airbnb_silver.silver_listings_la;
SELECT COUNT(*) AS listings_nyc FROM airbnb_lab3.airbnb_silver.silver_listings_nyc;

SELECT COUNT(*) AS cal_la FROM airbnb_lab3.airbnb_silver.silver_calendar_la;
SELECT COUNT(*) AS cal_nyc FROM airbnb_lab3.airbnb_silver.silver_calendar_nyc;

SELECT COUNT(*) AS gold_city FROM airbnb_lab3.airbnb_gold.gold_city_month_metrics;
SELECT COUNT(*) AS gold_neigh FROM airbnb_lab3.airbnb_gold.gold_neighbourhood_metrics;
SELECT COUNT(*) AS gold_roomtype FROM airbnb_lab3.airbnb_gold.gold_roomtype_share;
SELECT COUNT(*) AS gold_reviews FROM airbnb_lab3.airbnb_gold.gold_reviews_monthly;
SELECT COUNT(*) AS gold_cross FROM airbnb_lab3.airbnb_gold.gold_cross_city_compare;
