-- %%
WITH la AS (
  SELECT DISTINCT yyyymm FROM airbnb_lab3.airbnb_gold.gold_city_month_metrics WHERE city='LA'
),
nyc AS (
  SELECT DISTINCT yyyymm FROM airbnb_lab3.airbnb_gold.gold_city_month_metrics WHERE city='NYC'
)
SELECT COUNT(*) AS overlap_months
FROM la INNER JOIN nyc USING(yyyymm);
